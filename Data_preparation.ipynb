# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarsha1407/Machine-Learning-Projects/blob/main/Data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   52    1   0       125   212    0  ...      0      1.0      2   2     3       0
# 1   53    1   0       140   203    1  ...      1      3.1      0   0     3       0
# 2   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 3   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 4   62    0   0       138   294    1  ...      0      1.9      1   3     2       0
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  target
# 1020   59    1   1       140   221  ...      0.0      2   0     2       1
# 1021   60    1   0       125   258  ...      2.8      1   1     3       0
# 1022   47    1   0       110   275  ...      1.0      1   1     2       0
# 1023   50    0   0       110   254  ...      0.0      2   0     2       1
# 1024   54    1   0       120   188  ...      1.4      1   1     3       0
#
# [5 rows x 14 columns]

# %%
df.iloc[10:15]
# Out:
#     age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 10   71    0   0       112   149    0  ...      0      1.6      1   0     2       1
# 11   43    0   0       132   341    1  ...      1      3.0      1   0     3       0
# 12   34    0   1       118   210    0  ...      0      0.7      2   0     2       1
# 13   51    1   0       140   298    0  ...      1      4.2      1   3     3       0
# 14   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
#
# [5 rows x 14 columns]

# %%
df.iloc[[10,20,30]]
# Out:
#     age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 10   71    0   0       112   149    0  ...      0      1.6      1   0     2       1
# 20   60    1   2       140   185    0  ...      0      3.0      1   0     2       0
# 30   44    1   0       120   169    0  ...      1      2.8      0   0     1       0
#
# [3 rows x 14 columns]

# %%
df.age
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
df['age']
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
df[['age','cp','chol']]
# Out:
#       age  cp  chol
# 0      52   0   212
# 1      53   0   203
# 2      70   0   174
# 3      61   0   203
# 4      62   0   294
# ...   ...  ..   ...
# 1020   59   1   221
# 1021   60   0   258
# 1022   47   0   275
# 1023   50   0   254
# 1024   54   0   188
#
# [1025 rows x 3 columns]

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.memory_usage()
# Out:
# Index        132
# age         8200
# sex         8200
# cp          8200
# trestbps    8200
# chol        8200
# fbs         8200
# restecg     8200
# thalach     8200
# exang       8200
# oldpeak     8200
# slope       8200
# ca          8200
# thal        8200
# target      8200
# dtype: int64

# %%
df.memory_usage().sum()
# Out:
# np.int64(114932)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#                age          sex  ...         thal       target
# count  1025.000000  1025.000000  ...  1025.000000  1025.000000
# mean     54.434146     0.695610  ...     2.323902     0.513171
# std       9.072290     0.460373  ...     0.620660     0.500070
# min      29.000000     0.000000  ...     0.000000     0.000000
# 25%      48.000000     0.000000  ...     2.000000     0.000000
# 50%      56.000000     1.000000  ...     2.000000     1.000000
# 75%      61.000000     1.000000  ...     3.000000     1.000000
# max      77.000000     1.000000  ...     3.000000     1.000000
#
# [8 rows x 14 columns]

# %%
df['age'].describe()
# Out:
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64

# %%
df[['age','cp','chol']].describe()
# Out:
#                age           cp        chol
# count  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.942439   246.00000
# std       9.072290     1.029641    51.59251
# min      29.000000     0.000000   126.00000
# 25%      48.000000     0.000000   211.00000
# 50%      56.000000     1.000000   240.00000
# 75%      61.000000     2.000000   275.00000
# max      77.000000     3.000000   564.00000

# %%
df['age'].min()
# Out:
# 29

# %%
df['age'].mean()
# Out:
# np.float64(54.43414634146342)

# %%
(df == 0).sum()
# Out:
# age           0
# sex         312
# cp          497
# trestbps      0
# chol          0
# fbs         872
# restecg     497
# thalach       0
# exang       680
# oldpeak     329
# slope        74
# ca          578
# thal          7
# target      499
# dtype: int64

# %%
df[(df['thal'] == 0)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 14    52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 319   53    0   2       128   216    0  ...      0      0.0      2   0     0       1
# 329   53    0   2       128   216    0  ...      0      0.0      2   0     0       1
# 359   53    0   2       128   216    0  ...      0      0.0      2   0     0       1
# 686   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 734   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 893   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
#
# [7 rows x 14 columns]

# %%
df[(df['age']>50)]
# Out:
#       age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  target
# 0      52    1   0       125   212  ...      1.0      2   2     3       0
# 1      53    1   0       140   203  ...      3.1      0   0     3       0
# 2      70    1   0       145   174  ...      2.6      0   0     3       0
# 3      61    1   0       148   203  ...      0.0      2   1     3       0
# 4      62    0   0       138   294  ...      1.9      1   3     2       0
# ...   ...  ...  ..       ...   ...  ...      ...    ...  ..   ...     ...
# 1016   65    1   3       138   282  ...      1.4      1   1     2       0
# 1017   53    1   0       123   282  ...      2.0      1   2     3       0
# 1020   59    1   1       140   221  ...      0.0      2   0     2       1
# 1021   60    1   0       125   258  ...      2.8      1   1     3       0
# 1024   54    1   0       120   188  ...      1.4      1   1     3       0
#
# [710 rows x 14 columns]

# %%
df[(df['age'] == 29)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 60    29    1   1       130   204    0  ...      0      0.0      2   0     2       1
# 64    29    1   1       130   204    0  ...      0      0.0      2   0     2       1
# 118   29    1   1       130   204    0  ...      0      0.0      2   0     2       1
# 668   29    1   1       130   204    0  ...      0      0.0      2   0     2       1
#
# [4 rows x 14 columns]

# %%
train, test = train_test_split(df, train_size=0.8, random_state = 42)

# %%
train.shape
# Out:
# (820, 14)

# %%
test.shape
# Out:
# (205, 14)

# %%
train.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 835   49    1   2       118   149    0  ...      0      0.8      2   3     2       0
# 137   64    0   0       180   325    0  ...      1      0.0      2   0     2       1
# 534   54    0   2       108   267    0  ...      0      0.0      2   0     2       1
# 495   59    1   0       135   234    0  ...      0      0.5      1   0     3       1
# 244   51    1   2       125   245    1  ...      0      2.4      1   0     2       1
#
# [5 rows x 14 columns]

# %%
test.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 527   62    0   0       124   209    0  ...      0      0.0      2   0     2       1
# 359   53    0   2       128   216    0  ...      0      0.0      2   0     0       1
# 447   55    1   0       160   289    0  ...      1      0.8      1   1     3       0
# 31    50    0   1       120   244    0  ...      0      1.1      2   0     2       1
# 621   48    1   0       130   256    1  ...      1      0.0      2   2     3       0
#
# [5 rows x 14 columns]

# %%
TN,FP,FN,TP = 395,55,5,45

# %%
confusion_matrix = [[395,55],[5,45]]

# %%
confusion_matrix
# Out:
# [[395, 55], [5, 45]]

# %%
accuracy_score = (TP+TN)/(TP+TN+FP+FN)

# %%
accuracy_score
# Out:
# 0.88

# %%
precision_score = TP/ (TP+FP)

# %%
precision_score
# Out:
# 0.45

# %%
recall_score = TP/(TP+FN)

# %%
recall_score
# Out:
# 0.9

# %%
f1_score = (2*precision_score*recall_score)/(precision_score+recall_score)

# %%
f1_score
# Out:
# 0.6
